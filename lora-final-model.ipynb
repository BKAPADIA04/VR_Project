# %%
import numpy as np
import pandas as pd

# %%
final_df = pd.read_csv('/kaggle/input/finale-dataset/train_dataset.csv')
test_df = pd.read_csv('/kaggle/input/finale-dataset/test_dataset.csv')

# %%
# final_df= final_df.head(38000)

# %%
final_df.head()
# Out:
#       image_id                              question        answer  \
# 0  71BN3iMoGkL    What are the figurines sitting on?         Bench
# 1  71AH7yyOgCL  What brand is the mobile phone case?        Solimo
# 2  71ag2dwtVfL                   What brand is this?  AmazonBasics
# 3  61yqMXIGHVL  What lining do these envelopes have?        Bubble
# 4  71d57C76BpL              What is the shade shape?          Drum
#
#               path
# 0  9d/9dd2d3f1.jpg
# 1  f3/f3ab1fbf.jpg
# 2  62/62075c07.jpg
# 3  2d/2d483c93.jpg
# 4  b8/b8b510a2.jpg

# %%
len(final_df)
# Out:
# 63639

# %%
len(test_df)
# Out:
# 15910

# %% [markdown]
# ## LORA MODEL

# %%
# !pip install -q peft accelerate

# %%
import os
import torch
import pandas as pd
from PIL import Image
from torch.utils.data import DataLoader, Dataset
from transformers import BlipProcessor, BlipForQuestionAnswering, get_scheduler
from peft import get_peft_model, LoraConfig, TaskType, PeftModel

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")

model = BlipForQuestionAnswering.from_pretrained(
    "Salesforce/blip-vqa-base"
).to(device)

_orig_forward = model.forward

def _forward_no_inputs_embeds(*args, **kwargs):
    kwargs.pop("inputs_embeds", None)
    kwargs.pop("decoder_inputs_embeds", None)  # Use `None` as default
    return _orig_forward(*args, **kwargs)

model.forward = _forward_no_inputs_embeds

lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["query", "value"],
    lora_dropout=0.1,
    bias="none",
    task_type=TaskType.SEQ_2_SEQ_LM
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()

# df = pd.read_csv("/kaggle/input/finale-dataset/train_dataset.csv")  # assumes columns: 'path', 'question', 'answer'

class BlipVQADataset(Dataset):
    def __init__(self, df, image_dir, processor):
        self.df = df
        self.image_dir = image_dir
        self.processor = processor

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        image_path = os.path.join(self.image_dir, row['path'])
        image = Image.open(image_path).convert("RGB")
        question = str(row["question"])
        answer = str(row["answer"])

        inputs = self.processor(images=image, text=question, return_tensors="pt", padding='max_length', max_length=128, truncation=True)
        inputs = {k: v.squeeze(0) for k, v in inputs.items()}
        inputs["labels"] = processor.tokenizer(answer, return_tensors="pt", padding='max_length', max_length=32, truncation=True).input_ids.squeeze(0)
        return inputs

def collate_fn(batch):
    pixel_values = torch.stack([item["pixel_values"] for item in batch])
    input_ids = torch.stack([item["input_ids"] for item in batch])
    attention_mask = torch.stack([item["attention_mask"] for item in batch])
    labels = torch.nn.utils.rnn.pad_sequence(
        [item["labels"] for item in batch], batch_first=True, padding_value=-100
    )
    return {
        "pixel_values": pixel_values,
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "labels": labels
    }

image_dir = "/kaggle/input/vr-dataset/small/small/"
dataset = BlipVQADataset(final_df, image_dir, processor)
dataloader = DataLoader(dataset, batch_size=8, shuffle=True, collate_fn=collate_fn, num_workers=2)

optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5)
lr_scheduler = get_scheduler("cosine", optimizer=optimizer, num_warmup_steps=100, num_training_steps=len(dataloader)*3)

scaler = torch.cuda.amp.GradScaler()

model.train()
for epoch in range(2):
    total_loss = 0
    for step, batch in enumerate(dataloader):
        pixel_values = batch["pixel_values"].to(device, dtype=torch.float16)
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            # Correct forward pass without 'inputs_embeds'
            outputs = model(
                pixel_values=pixel_values,  # Image features
                input_ids=input_ids,        # Text input (question)
                attention_mask=attention_mask,  # Attention mask
                labels=labels               # Labels for the answer
            )
            loss = outputs.loss

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        lr_scheduler.step()

        total_loss += loss.item()
        if step % 10 == 0:
            print(f"Epoch {epoch+1}, Step {step}, Loss: {loss.item():.4f}")

    print(f"Epoch {epoch+1} complete. Avg Loss: {total_loss / len(dataloader):.4f}")

save_path = "/kaggle/working/blip_lora_adapter2"
model.save_pretrained(save_path)
print(f"LoRA adapter saved at: {save_path}")
# Out:
# 2025-05-18 05:27:25.130534: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747546045.158007     100 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747546045.165568     100 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device: cuda
# trainable params: 2,359,296 || all params: 387,031,868 || trainable%: 0.6096
# /tmp/ipykernel_100/1580441947.py:83: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /tmp/ipykernel_100/1580441947.py:95: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# Epoch 1, Step 0, Loss: 10.4506
# Epoch 1, Step 10, Loss: 10.5323
# Epoch 1, Step 20, Loss: 10.5198
# Epoch 1, Step 30, Loss: 10.3073
# Epoch 1, Step 40, Loss: 10.3607
# Epoch 1, Step 50, Loss: 10.1615
# Epoch 1, Step 60, Loss: 9.9935
# Epoch 1, Step 70, Loss: 9.8585
# Epoch 1, Step 80, Loss: 9.6610
# Epoch 1, Step 90, Loss: 9.4874
# Epoch 1, Step 100, Loss: 9.5259
# Epoch 1, Step 110, Loss: 9.3614
# Epoch 1, Step 120, Loss: 9.2823
# Epoch 1, Step 130, Loss: 9.1261
# Epoch 1, Step 140, Loss: 9.0051
# Epoch 1, Step 150, Loss: 9.0074
# Epoch 1, Step 160, Loss: 8.9601
# Epoch 1, Step 170, Loss: 8.8785
# Epoch 1, Step 180, Loss: 8.8061
# Epoch 1, Step 190, Loss: 8.7187
# Epoch 1, Step 200, Loss: 8.5628
# Epoch 1, Step 210, Loss: 8.7300
# Epoch 1, Step 220, Loss: 8.6064
# Epoch 1, Step 230, Loss: 8.6122
# Epoch 1, Step 240, Loss: 8.4885
# Epoch 1, Step 250, Loss: 8.4364
# Epoch 1, Step 260, Loss: 8.5511
# Epoch 1, Step 270, Loss: 8.4695
# Epoch 1, Step 280, Loss: 8.4925
# Epoch 1, Step 290, Loss: 8.4464
# Epoch 1, Step 300, Loss: 8.5051
# Epoch 1, Step 310, Loss: 8.3570
# Epoch 1, Step 320, Loss: 8.4334
# Epoch 1, Step 330, Loss: 8.3970
# Epoch 1, Step 340, Loss: 8.3712
# Epoch 1, Step 350, Loss: 8.2641
# Epoch 1, Step 360, Loss: 8.3746
# Epoch 2, Step 50, Loss: 8.0328
# Epoch 2, Step 60, Loss: 8.1303
# Epoch 2, Step 70, Loss: 8.0309
# Epoch 2, Step 80, Loss: 8.1680
# Epoch 2, Step 90, Loss: 8.0771
# Epoch 2, Step 100, Loss: 8.0096
# Epoch 2, Step 110, Loss: 7.9209
# Epoch 2, Step 120, Loss: 8.0639
# Epoch 2, Step 130, Loss: 8.1825
# Epoch 2, Step 140, Loss: 8.0491
# Epoch 2, Step 150, Loss: 8.0906
# Epoch 2, Step 160, Loss: 8.0317
# Epoch 2, Step 170, Loss: 8.1030
# Epoch 2, Step 180, Loss: 8.1508
# Epoch 2, Step 190, Loss: 8.1072
# Epoch 2, Step 200, Loss: 8.0841
# Epoch 2, Step 210, Loss: 8.0943
# Epoch 2, Step 220, Loss: 8.1159
# Epoch 2, Step 230, Loss: 7.8816
# Epoch 2, Step 240, Loss: 8.0629
# Epoch 2, Step 250, Loss: 7.9640
# Epoch 2, Step 260, Loss: 8.1990
# Epoch 2, Step 270, Loss: 8.0967
# Epoch 2, Step 280, Loss: 8.1119
# Epoch 2, Step 290, Loss: 8.0803
# Epoch 2, Step 300, Loss: 8.0957
# Epoch 2, Step 310, Loss: 8.1656
# Epoch 2, Step 320, Loss: 8.1369
# Epoch 2, Step 330, Loss: 7.9517
# Epoch 2, Step 340, Loss: 8.0631
# Epoch 2, Step 350, Loss: 8.1298
# Epoch 2, Step 360, Loss: 8.1173
# Epoch 2, Step 370, Loss: 8.1296
# Epoch 2, Step 380, Loss: 8.0497
# Epoch 2, Step 390, Loss: 8.1850
# Epoch 2, Step 400, Loss: 7.9889
# Epoch 2, Step 410, Loss: 8.0718
# Epoch 2, Step 420, Loss: 8.0735
# Epoch 2, Step 430, Loss: 8.0500
# Epoch 2, Step 440, Loss: 8.1372
# Epoch 2, Step 450, Loss: 8.0146
# Epoch 2, Step 460, Loss: 8.1127
# Epoch 2, Step 470, Loss: 8.0464
# Epoch 2, Step 480, Loss: 8.1174
# Epoch 2, Step 490, Loss: 7.9611
# Epoch 2, Step 500, Loss: 8.2285
# Epoch 2, Step 510, Loss: 8.0409
# Epoch 2, Step 520, Loss: 8.0919
# Epoch 2, Step 530, Loss: 8.0223
# Epoch 2, Step 540, Loss: 8.1105
# Epoch 2, Step 550, Loss: 8.1371
# Epoch 2, Step 560, Loss: 8.1040
# Epoch 2, Step 570, Loss: 8.0661
# Epoch 2, Step 580, Loss: 8.0859
# Epoch 2, Step 590, Loss: 7.9903
# Epoch 2, Step 600, Loss: 8.0122
# Epoch 2, Step 610, Loss: 8.0882
# Epoch 2, Step 620, Loss: 8.0487
# Epoch 2, Step 630, Loss: 8.0820
# Epoch 2, Step 640, Loss: 8.2055
# Epoch 2, Step 650, Loss: 8.1279
# Epoch 2, Step 660, Loss: 8.0427
# Epoch 2, Step 670, Loss: 8.1158
# Epoch 2, Step 680, Loss: 8.0334
# Epoch 2, Step 690, Loss: 8.1185
# Epoch 2, Step 700, Loss: 8.1243
# Epoch 2, Step 710, Loss: 7.9898
# Epoch 2, Step 720, Loss: 8.1576
# Epoch 2, Step 730, Loss: 7.9841
# Epoch 2, Step 740, Loss: 8.0749
# Epoch 2, Step 750, Loss: 8.0583
# Epoch 2, Step 760, Loss: 8.1461
# Epoch 2, Step 770, Loss: 8.1248
# Epoch 2, Step 780, Loss: 8.0200
# Epoch 2, Step 790, Loss: 7.9864
# Epoch 2, Step 800, Loss: 8.1172
# Epoch 2, Step 810, Loss: 7.9974
# Epoch 2, Step 820, Loss: 8.1673
# Epoch 2, Step 830, Loss: 8.1373
# Epoch 2, Step 840, Loss: 8.1559
# Epoch 2, Step 850, Loss: 8.1448
# Epoch 2, Step 860, Loss: 8.0867
# Epoch 2, Step 870, Loss: 8.1454
# Epoch 2, Step 880, Loss: 8.0367
# Epoch 2, Step 890, Loss: 8.0594
# Epoch 2, Step 900, Loss: 8.1431
# Epoch 2, Step 910, Loss: 8.1093
# Epoch 2, Step 920, Loss: 8.0282
# Epoch 2, Step 930, Loss: 8.1169
# Epoch 2, Step 940, Loss: 8.1121
# Epoch 2, Step 950, Loss: 8.1143
# Epoch 2, Step 960, Loss: 8.1237
# Epoch 2, Step 970, Loss: 8.1380
# Epoch 2, Step 980, Loss: 7.9853
# Epoch 2, Step 990, Loss: 8.0996
# Epoch 2, Step 1000, Loss: 8.1383
# Epoch 2, Step 1010, Loss: 8.1454
# Epoch 2, Step 1020, Loss: 8.1330
# Epoch 2, Step 1030, Loss: 8.2279
# Epoch 2, Step 1040, Loss: 8.2342
# Epoch 2, Step 1050, Loss: 8.1485
# Epoch 2, Step 1060, Loss: 8.0422
# Epoch 2, Step 1070, Loss: 8.0496
# Epoch 2, Step 1080, Loss: 8.0979
# Epoch 2, Step 1090, Loss: 8.0925
# Epoch 2, Step 1100, Loss: 8.1693
# Epoch 2, Step 1110, Loss: 8.0353
# Epoch 2, Step 1120, Loss: 8.0670
# Epoch 2, Step 1130, Loss: 8.0703
# Epoch 2, Step 1140, Loss: 8.0508
# Epoch 2, Step 1150, Loss: 8.0605
# Epoch 2, Step 1160, Loss: 8.0695
# Epoch 2, Step 1170, Loss: 8.1300
# Epoch 2, Step 1180, Loss: 8.0676
# Epoch 2, Step 1190, Loss: 8.2016
# Epoch 2, Step 1200, Loss: 8.1356
# Epoch 2, Step 1210, Loss: 8.1751
# Epoch 2, Step 1220, Loss: 8.0946
# Epoch 2, Step 1230, Loss: 8.0659
# Epoch 2, Step 1240, Loss: 8.0671
# Epoch 2, Step 1250, Loss: 8.1928
# Epoch 2, Step 1260, Loss: 8.0140
# Epoch 2, Step 1270, Loss: 7.9615
# Epoch 2, Step 1280, Loss: 8.1760
# Epoch 2, Step 1290, Loss: 8.0614
# Epoch 2, Step 1300, Loss: 8.0229
# Epoch 2, Step 1310, Loss: 8.0096
# Epoch 2, Step 1320, Loss: 7.9896
# Epoch 2, Step 1330, Loss: 8.1464
# Epoch 2, Step 1340, Loss: 8.1304
# Epoch 2, Step 1350, Loss: 8.0614
# Epoch 2, Step 1360, Loss: 8.0765
# Epoch 2, Step 1370, Loss: 8.0541
# Epoch 2, Step 1380, Loss: 8.0071
# Epoch 2, Step 1390, Loss: 8.0968
# Epoch 2, Step 1400, Loss: 8.1263
# Epoch 2, Step 1410, Loss: 8.1553
# Epoch 2, Step 1420, Loss: 7.9005
# Epoch 2, Step 1430, Loss: 8.1391
# Epoch 2, Step 1440, Loss: 7.9999
# Epoch 2, Step 1450, Loss: 8.1658
# Epoch 2, Step 1460, Loss: 8.0418
# Epoch 2, Step 1470, Loss: 8.1467
# Epoch 2, Step 1480, Loss: 8.0025
# Epoch 2, Step 1490, Loss: 8.0069
# Epoch 2, Step 1500, Loss: 8.2038
# Epoch 2, Step 1510, Loss: 8.1100
# Epoch 2, Step 1520, Loss: 8.0321
# Epoch 2, Step 1530, Loss: 8.1177
# Epoch 2, Step 1540, Loss: 8.0991
# Epoch 2, Step 1550, Loss: 8.1145
# Epoch 2, Step 1560, Loss: 8.0278
# Epoch 2, Step 1570, Loss: 8.0935
# Epoch 2, Step 1580, Loss: 8.0613
# Epoch 2, Step 1590, Loss: 8.0535
# Epoch 2, Step 1600, Loss: 8.1225
# Epoch 2, Step 1610, Loss: 7.9998
# Epoch 2, Step 1620, Loss: 8.0585
# Epoch 2, Step 1630, Loss: 8.1409
# Epoch 2, Step 1640, Loss: 7.9874
# Epoch 2, Step 1650, Loss: 8.1301
# Epoch 2, Step 1660, Loss: 8.1132
# Epoch 2, Step 1670, Loss: 8.1257
# Epoch 2, Step 1680, Loss: 8.0986
# Epoch 2, Step 1690, Loss: 8.0930
# Epoch 2, Step 1700, Loss: 8.1853
# Epoch 2, Step 1710, Loss: 8.1395
# Epoch 2, Step 1720, Loss: 8.0618
# Epoch 2, Step 1730, Loss: 8.1168
# Epoch 2, Step 1740, Loss: 8.0132
# Epoch 2, Step 1750, Loss: 8.0361
# Epoch 2, Step 1760, Loss: 8.0957
# Epoch 2, Step 1770, Loss: 8.0129
# Epoch 2, Step 1780, Loss: 7.9471
# Epoch 2, Step 1790, Loss: 8.0695
# Epoch 2, Step 1800, Loss: 8.0871
# Epoch 2, Step 1810, Loss: 8.1064
# Epoch 2, Step 1820, Loss: 8.1711
# Epoch 2, Step 1830, Loss: 7.9547
# Epoch 2, Step 1840, Loss: 8.0498
# Epoch 2, Step 1850, Loss: 8.1296
# Epoch 2, Step 1860, Loss: 8.1721
# Epoch 2, Step 1870, Loss: 8.0705
# Epoch 2, Step 1880, Loss: 8.1531
# Epoch 2, Step 1890, Loss: 8.0693
# Epoch 2, Step 1900, Loss: 8.1585
# Epoch 2, Step 1910, Loss: 8.0636
# Epoch 2, Step 1920, Loss: 8.1754
# Epoch 2, Step 1930, Loss: 8.1284
# Epoch 2, Step 1940, Loss: 8.1049
# Epoch 2, Step 1950, Loss: 8.0876
# Epoch 2, Step 1960, Loss: 8.0887
# Epoch 2, Step 1970, Loss: 8.1527
# Epoch 2, Step 1980, Loss: 7.9703
# Epoch 2, Step 1990, Loss: 7.9977
# Epoch 2, Step 2000, Loss: 8.1036
# Epoch 2, Step 2010, Loss: 8.1142
# Epoch 2, Step 2020, Loss: 8.1360
# Epoch 2, Step 2030, Loss: 8.0971
# Epoch 2, Step 2040, Loss: 8.1345
# Epoch 2, Step 2050, Loss: 8.0781
# Epoch 2, Step 2060, Loss: 8.1334
# Epoch 2, Step 2070, Loss: 8.0627
# Epoch 2, Step 2080, Loss: 8.1615
# Epoch 2, Step 2090, Loss: 8.1274
# Epoch 2, Step 2100, Loss: 8.1222
# Epoch 2, Step 2110, Loss: 8.0187
# Epoch 2, Step 2120, Loss: 7.9492
# Epoch 2, Step 2130, Loss: 8.1550
# Epoch 2, Step 2140, Loss: 8.1077
# Epoch 2, Step 2150, Loss: 8.1188
# Epoch 2, Step 2160, Loss: 8.1081
# Epoch 2, Step 2170, Loss: 8.0955
# Epoch 2, Step 2180, Loss: 7.9989
# Epoch 2, Step 2190, Loss: 8.1181
# Epoch 2, Step 2200, Loss: 8.0749
# Epoch 2, Step 2210, Loss: 8.1304
# Epoch 2, Step 2220, Loss: 7.9929
# Epoch 2, Step 2230, Loss: 8.0636
# Epoch 2, Step 2240, Loss: 8.0182
# Epoch 2, Step 2250, Loss: 8.2112
# Epoch 2, Step 2260, Loss: 7.9683
# Epoch 2, Step 2270, Loss: 8.1611
# Epoch 2, Step 2280, Loss: 8.1680
# Epoch 2, Step 2290, Loss: 8.1254
# Epoch 2, Step 2300, Loss: 8.1239
# Epoch 2, Step 2310, Loss: 8.1540
# Epoch 2, Step 2320, Loss: 8.0790
# Epoch 2, Step 2330, Loss: 8.0679
# Epoch 2, Step 2340, Loss: 8.0940
# Epoch 2, Step 2350, Loss: 8.1260
# Epoch 2, Step 2360, Loss: 8.0974
# Epoch 2, Step 2370, Loss: 8.1222
# Epoch 2, Step 2380, Loss: 8.1221
# Epoch 2, Step 2390, Loss: 8.1619
# Epoch 2, Step 2400, Loss: 8.1060
# Epoch 2, Step 2410, Loss: 8.0620
# Epoch 2, Step 2420, Loss: 8.1355
# Epoch 2, Step 2430, Loss: 8.1513
# Epoch 2, Step 2440, Loss: 8.0589
# Epoch 2, Step 2450, Loss: 8.0929
# Epoch 2, Step 2460, Loss: 8.1150
# Epoch 2, Step 2470, Loss: 8.1988
# Epoch 2, Step 2480, Loss: 8.0846
# Epoch 2, Step 2490, Loss: 8.0681
# Epoch 2, Step 2500, Loss: 8.1483
# Epoch 2, Step 2510, Loss: 8.0814
# Epoch 2, Step 2520, Loss: 8.1345
# Epoch 2, Step 2530, Loss: 8.0325
# Epoch 2, Step 2540, Loss: 8.1366
# Epoch 2, Step 2550, Loss: 8.0999
# Epoch 2, Step 2560, Loss: 8.1326
# Epoch 2, Step 2570, Loss: 8.0824
# Epoch 2, Step 2580, Loss: 8.0487
# Epoch 2, Step 2590, Loss: 7.9825
# Epoch 2, Step 2600, Loss: 8.0656
# Epoch 2, Step 2610, Loss: 8.1152
# Epoch 2, Step 2620, Loss: 8.0236
# Epoch 2, Step 2630, Loss: 8.0552
# Epoch 2, Step 2640, Loss: 8.1330
# Epoch 2, Step 2650, Loss: 8.1192
# Epoch 2, Step 2660, Loss: 8.0781
# Epoch 2, Step 2670, Loss: 8.0294
# Epoch 2, Step 2680, Loss: 8.1189
# Epoch 2, Step 2690, Loss: 8.1385
# Epoch 2, Step 2700, Loss: 7.9591
# Epoch 2, Step 2710, Loss: 8.0500
# Epoch 2, Step 2720, Loss: 8.1459
# Epoch 2, Step 2730, Loss: 8.1568
# Epoch 2, Step 2740, Loss: 8.1096
# Epoch 2, Step 2750, Loss: 8.0924
# Epoch 2, Step 2760, Loss: 8.1107
# Epoch 2, Step 2770, Loss: 8.1905
# Epoch 2, Step 2780, Loss: 8.0130
# Epoch 2, Step 2790, Loss: 8.1907
# Epoch 2, Step 2800, Loss: 8.2430
# Epoch 2, Step 2810, Loss: 8.0945
# Epoch 2, Step 2820, Loss: 7.9740
# Epoch 2, Step 2830, Loss: 8.0188
# Epoch 2, Step 2840, Loss: 8.0619
# Epoch 2, Step 2850, Loss: 8.0715
# Epoch 2, Step 2860, Loss: 8.0009
# Epoch 2, Step 2870, Loss: 8.0775
# Epoch 2, Step 2880, Loss: 8.1278
# Epoch 2, Step 2890, Loss: 8.0295
# Epoch 2, Step 2900, Loss: 8.1396
# Epoch 2, Step 2910, Loss: 8.1591
# Epoch 2, Step 2920, Loss: 8.1011
# Epoch 2, Step 2930, Loss: 8.1420
# Epoch 2, Step 2940, Loss: 8.1862
# Epoch 2, Step 2950, Loss: 8.0845
# Epoch 2, Step 2960, Loss: 8.0262
# Epoch 2, Step 2970, Loss: 7.8733
# Epoch 2, Step 2980, Loss: 7.9544
# Epoch 2, Step 2990, Loss: 8.1027
# Epoch 2, Step 3000, Loss: 8.0048
# Epoch 2, Step 3010, Loss: 8.0279
# Epoch 2, Step 3020, Loss: 8.0723
# Epoch 2, Step 3030, Loss: 8.1669
# Epoch 2, Step 3040, Loss: 8.1201
# Epoch 2, Step 3050, Loss: 8.0357
# Epoch 2, Step 3060, Loss: 8.1069
# Epoch 2, Step 3070, Loss: 8.0491
# Epoch 2, Step 3080, Loss: 8.1440
# Epoch 2, Step 3090, Loss: 7.9782
# Epoch 2, Step 3100, Loss: 8.0520
# Epoch 2, Step 3110, Loss: 8.0933
# Epoch 2, Step 3120, Loss: 8.0251
# Epoch 2, Step 3130, Loss: 8.1426
# Epoch 2, Step 3140, Loss: 8.0859
# Epoch 2, Step 3150, Loss: 8.1651
# Epoch 2, Step 3160, Loss: 8.0124
# Epoch 2, Step 3170, Loss: 8.1442
# Epoch 2, Step 3180, Loss: 8.1432
# Epoch 2, Step 3190, Loss: 8.0327
# Epoch 2, Step 3200, Loss: 8.0066
# Epoch 2, Step 3210, Loss: 8.1428
# Epoch 2, Step 3220, Loss: 8.1055
# Epoch 2, Step 3230, Loss: 8.0636
# Epoch 2, Step 3240, Loss: 8.1763
# Epoch 2, Step 3250, Loss: 8.1572
# Epoch 2, Step 3260, Loss: 8.1228
# Epoch 2, Step 3270, Loss: 8.1429
# Epoch 2, Step 3280, Loss: 8.1602
# Epoch 2, Step 3290, Loss: 8.1087
# Epoch 2, Step 3300, Loss: 8.1462
# Epoch 2, Step 3310, Loss: 8.1650
# Epoch 2, Step 3320, Loss: 7.9680
# Epoch 2, Step 3330, Loss: 8.1500
# Epoch 2, Step 3340, Loss: 8.1162
# Epoch 2, Step 3350, Loss: 8.1069
# Epoch 2, Step 3360, Loss: 8.0890
# Epoch 2, Step 3370, Loss: 8.0358
# Epoch 2, Step 3380, Loss: 7.9793
# Epoch 2, Step 3390, Loss: 8.0690
# Epoch 2, Step 3400, Loss: 8.0829
# Epoch 2, Step 3410, Loss: 8.0658
# Epoch 2, Step 3420, Loss: 8.0604
# Epoch 2, Step 3430, Loss: 8.0642
# Epoch 2, Step 3440, Loss: 8.0945
# Epoch 2, Step 3450, Loss: 8.1620
# Epoch 2, Step 3460, Loss: 7.9993
# Epoch 2, Step 3470, Loss: 8.0156
# Epoch 2, Step 3480, Loss: 7.9572
# Epoch 2, Step 3490, Loss: 8.1851
# Epoch 2, Step 3500, Loss: 8.0944
# Epoch 2, Step 3510, Loss: 8.0822
# Epoch 2, Step 3520, Loss: 8.0324
# Epoch 2, Step 3530, Loss: 8.1151
# Epoch 2, Step 3540, Loss: 8.1268
# Epoch 2, Step 3550, Loss: 8.0457
# Epoch 2, Step 3560, Loss: 8.0694
# Epoch 2, Step 3570, Loss: 8.1124
# Epoch 2, Step 3580, Loss: 8.0333
# Epoch 2, Step 3590, Loss: 8.0785
# Epoch 2, Step 3600, Loss: 7.9561
# Epoch 2, Step 3610, Loss: 8.1341
# Epoch 2, Step 3620, Loss: 8.0324
# Epoch 2, Step 3630, Loss: 8.0080
# Epoch 2, Step 3640, Loss: 8.0582
# Epoch 2, Step 3650, Loss: 8.0096
# Epoch 2, Step 3660, Loss: 8.0850
# Epoch 2, Step 3670, Loss: 8.0359
# Epoch 2, Step 3680, Loss: 8.1095
# Epoch 2, Step 3690, Loss: 8.0457
# Epoch 2, Step 3700, Loss: 8.0606
# Epoch 2, Step 3710, Loss: 8.1659
# Epoch 2, Step 3720, Loss: 8.0610
# Epoch 2, Step 3730, Loss: 8.1264
# Epoch 2, Step 3740, Loss: 7.8704
# Epoch 2, Step 3750, Loss: 8.1459
# Epoch 2, Step 3760, Loss: 7.9330
# Epoch 2, Step 3770, Loss: 8.0574
# Epoch 2, Step 3780, Loss: 8.1303
# Epoch 2, Step 3790, Loss: 8.0957
# Epoch 2, Step 3800, Loss: 8.0231
# Epoch 2, Step 3810, Loss: 8.1902
# Epoch 2, Step 3820, Loss: 8.1492
# Epoch 2, Step 3830, Loss: 8.1492
# Epoch 2, Step 3840, Loss: 8.1008
# Epoch 2, Step 3850, Loss: 8.0113
# Epoch 2, Step 3860, Loss: 8.1873
# Epoch 2, Step 3870, Loss: 8.1511
# Epoch 2, Step 3880, Loss: 8.1205
# Epoch 2, Step 3890, Loss: 8.0985
# Epoch 2, Step 3900, Loss: 8.1489
# Epoch 2, Step 3910, Loss: 7.9862
# Epoch 2, Step 3920, Loss: 8.0456
# Epoch 2, Step 3930, Loss: 8.2120
# Epoch 2, Step 3940, Loss: 8.0528
# Epoch 2, Step 3950, Loss: 8.1278
# Epoch 2, Step 3960, Loss: 8.0904
# Epoch 2, Step 3970, Loss: 8.1030
# Epoch 2, Step 3980, Loss: 8.1087
# Epoch 2, Step 3990, Loss: 8.0544
# Epoch 2, Step 4000, Loss: 8.1129
# Epoch 2, Step 4010, Loss: 8.1412
# Epoch 2, Step 4020, Loss: 8.1136
# Epoch 2, Step 4030, Loss: 8.1236
# Epoch 2, Step 4040, Loss: 7.9912
# Epoch 2, Step 4050, Loss: 8.1561
# Epoch 2, Step 4060, Loss: 8.1094
# Epoch 2, Step 4070, Loss: 8.0337
# Epoch 2, Step 4080, Loss: 8.0892
# Epoch 2, Step 4090, Loss: 8.0392
# Epoch 2, Step 4100, Loss: 8.0352
# Epoch 2, Step 4110, Loss: 7.9160
# Epoch 2, Step 4120, Loss: 8.1715
# Epoch 2, Step 4130, Loss: 8.0480
# Epoch 2, Step 4140, Loss: 8.0855
# Epoch 2, Step 4150, Loss: 8.0230
# Epoch 2, Step 4160, Loss: 8.1598
# Epoch 2, Step 4170, Loss: 8.1944
# Epoch 2, Step 4180, Loss: 8.0842
# Epoch 2, Step 4190, Loss: 7.9989
# Epoch 2, Step 4200, Loss: 8.0310
# Epoch 2, Step 4210, Loss: 8.1416
# Epoch 2, Step 4220, Loss: 8.1361
# Epoch 2, Step 4230, Loss: 8.1137
# Epoch 2, Step 4240, Loss: 7.9116
# Epoch 2, Step 4250, Loss: 8.0493
# Epoch 2, Step 4260, Loss: 8.1709
# Epoch 2, Step 4270, Loss: 8.1822
# Epoch 2, Step 4280, Loss: 8.1849
# Epoch 2, Step 4290, Loss: 8.0278
# Epoch 2, Step 4300, Loss: 8.0807
# Epoch 2, Step 4310, Loss: 8.0680
# Epoch 2, Step 4320, Loss: 8.1380
# Epoch 2, Step 4330, Loss: 8.1060
# Epoch 2, Step 4340, Loss: 8.0354
# Epoch 2, Step 4350, Loss: 8.0232
# Epoch 2, Step 4360, Loss: 7.9267
# Epoch 2, Step 4370, Loss: 8.1079
# Epoch 2, Step 4380, Loss: 8.0691
# Epoch 2, Step 4390, Loss: 8.2460
# Epoch 2, Step 4400, Loss: 8.0729
# Epoch 2, Step 4410, Loss: 8.1652
# Epoch 2, Step 4420, Loss: 8.0933
# Epoch 2, Step 4430, Loss: 8.0358
# Epoch 2, Step 4440, Loss: 8.1587
# Epoch 2, Step 4450, Loss: 8.0609
# Epoch 2, Step 4460, Loss: 8.0832
# Epoch 2, Step 4470, Loss: 8.1345
# Epoch 2, Step 4480, Loss: 8.0827
# Epoch 2, Step 4490, Loss: 8.1225
# Epoch 2, Step 4500, Loss: 7.9798
# Epoch 2, Step 4510, Loss: 8.0798
# Epoch 2, Step 4520, Loss: 8.0683
# Epoch 2, Step 5800, Loss: 8.0016
# Epoch 2, Step 5810, Loss: 8.1377
# Epoch 2, Step 5820, Loss: 8.1895
# Epoch 2, Step 5830, Loss: 8.0139
# Epoch 2, Step 5840, Loss: 8.1451
# Epoch 2, Step 5850, Loss: 8.0411
# Epoch 2, Step 5860, Loss: 8.1435
# Epoch 2, Step 5870, Loss: 8.1268
# Epoch 2, Step 5880, Loss: 8.1986
# Epoch 2, Step 5890, Loss: 8.1477
# Epoch 2, Step 5900, Loss: 8.0746
# Epoch 2, Step 5910, Loss: 7.9487
# Epoch 2, Step 5920, Loss: 7.9948
# Epoch 2, Step 5930, Loss: 7.9921
# Epoch 2, Step 5940, Loss: 8.1076
# Epoch 2, Step 5950, Loss: 8.1111
# Epoch 2, Step 5960, Loss: 8.0836
# Epoch 2, Step 5970, Loss: 8.1503
# Epoch 2, Step 5980, Loss: 8.1283
# Epoch 2, Step 5990, Loss: 8.0874
# Epoch 2, Step 6000, Loss: 8.1363
# Epoch 2, Step 6010, Loss: 7.9733
# Epoch 2, Step 6020, Loss: 8.0186
# Epoch 2, Step 6030, Loss: 8.0489
# Epoch 2, Step 6040, Loss: 8.1128
# Epoch 2, Step 6050, Loss: 8.1587
# Epoch 2, Step 6060, Loss: 8.1363
# Epoch 2, Step 6070, Loss: 8.0172
# Epoch 2, Step 6080, Loss: 8.0266
# Epoch 2, Step 6090, Loss: 8.2033
# Epoch 2, Step 6100, Loss: 7.9790
# Epoch 2, Step 6110, Loss: 8.1129
# Epoch 2, Step 6120, Loss: 7.9964
# Epoch 2, Step 6130, Loss: 8.0764
# Epoch 2, Step 6140, Loss: 8.1315
# Epoch 2, Step 6150, Loss: 8.0895
# Epoch 2, Step 6160, Loss: 8.0997
# Epoch 2, Step 6170, Loss: 7.9286
# Epoch 2, Step 6180, Loss: 8.0363
# Epoch 2, Step 6190, Loss: 8.0223
# Epoch 2, Step 6200, Loss: 8.0698
# Epoch 2, Step 6210, Loss: 8.0748
# Epoch 2, Step 6220, Loss: 8.0678
# Epoch 2, Step 6230, Loss: 8.0989
# Epoch 2, Step 6240, Loss: 8.0507
# Epoch 2, Step 6250, Loss: 8.0444
# Epoch 2, Step 6260, Loss: 7.9575
# Epoch 2, Step 6270, Loss: 8.1053
# Epoch 2, Step 6280, Loss: 8.0335
# Epoch 2, Step 6290, Loss: 7.9502
# Epoch 2, Step 6300, Loss: 8.1649
# Epoch 2, Step 6310, Loss: 8.0826
# Epoch 2, Step 6320, Loss: 8.0817
# Epoch 2, Step 6330, Loss: 8.1519
# Epoch 2, Step 6340, Loss: 8.0781
# Epoch 2, Step 6350, Loss: 8.1560
# Epoch 2, Step 6360, Loss: 8.1234
# Epoch 2, Step 6370, Loss: 8.0569
# Epoch 2, Step 6380, Loss: 8.0700
# Epoch 2, Step 6390, Loss: 8.1210
# Epoch 2, Step 6400, Loss: 8.1497
# Epoch 2, Step 6410, Loss: 8.0464
# Epoch 2, Step 6420, Loss: 7.9747
# Epoch 2, Step 6430, Loss: 8.0669
# Epoch 2, Step 7710, Loss: 8.1420
# Epoch 2, Step 7720, Loss: 8.1405
# Epoch 2, Step 7730, Loss: 8.0310
# Epoch 2, Step 7740, Loss: 8.0653
# Epoch 2, Step 7750, Loss: 7.9503
# Epoch 2, Step 7760, Loss: 8.0127
# Epoch 2, Step 7770, Loss: 8.1920
# Epoch 2, Step 7780, Loss: 8.0517
# Epoch 2, Step 7790, Loss: 7.9853
# Epoch 2, Step 7800, Loss: 7.8481
# Epoch 2, Step 7810, Loss: 8.0226
# Epoch 2, Step 7820, Loss: 8.1735
# Epoch 2, Step 7830, Loss: 8.0884
# Epoch 2, Step 7840, Loss: 8.0947
# Epoch 2, Step 7850, Loss: 8.1940
# Epoch 2, Step 7860, Loss: 8.0623
# Epoch 2, Step 7870, Loss: 8.0273
# Epoch 2, Step 7880, Loss: 8.0549
# Epoch 2, Step 7890, Loss: 8.0404
# Epoch 2, Step 7900, Loss: 8.1262
# Epoch 2, Step 7910, Loss: 8.1433
# Epoch 2, Step 7920, Loss: 8.0946
# Epoch 2, Step 7930, Loss: 8.1415
# Epoch 2, Step 7940, Loss: 8.1686
# Epoch 2, Step 7950, Loss: 8.1004
# Epoch 2 complete. Avg Loss: 8.0808
# LoRA adapter saved at: /kaggle/working/blip_lora_adapter2

# %%
# !zip -r /kaggle/working/blip_lora_adapter.zip /kaggle/working/blip_lora_adapter2

# %% [markdown]
# ### MODEL DEPLOYED ON HUGGING FACE

# %% [markdown]
# # INFERENCE - LORA MODEL

# %%
import os
import torch
from transformers import BlipProcessor, BlipForQuestionAnswering
from peft import PeftModel
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import pandas as pd

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")

model = BlipForQuestionAnswering.from_pretrained(
    "Salesforce/blip-vqa-base",
    device_map='auto'
)
model = PeftModel.from_pretrained(model, "bk45/blip-vqa-finetuned").to(device)
model.eval()
# Out:
# adapter_config.json:   0%|          | 0.00/721 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/18.9M [00:00<?, ?B/s]
# PeftModelForSeq2SeqLM(
#   (base_model): LoraModel(
#     (model): BlipForQuestionAnswering(
#       (vision_model): BlipVisionModel(
#         (embeddings): BlipVisionEmbeddings(
#           (patch_embedding): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#         )
#         (encoder): BlipEncoder(
#           (layers): ModuleList(
#             (0-11): 12 x BlipEncoderLayer(
#               (self_attn): BlipAttention(
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (qkv): Linear(in_features=768, out_features=2304, bias=True)
#                 (projection): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (mlp): BlipMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear(in_features=768, out_features=3072, bias=True)
#                 (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#               (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#       (text_encoder): BlipTextModel(
#         (embeddings): BlipTextEmbeddings(
#           (word_embeddings): Embedding(30524, 768, padding_idx=0)
#           (position_embeddings): Embedding(512, 768)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (encoder): BlipTextEncoder(
#           (layer): ModuleList(
#             (0-11): 12 x BlipTextLayer(
#               (attention): BlipTextAttention(
#                 (self): BlipTextSelfAttention(
#                   (query): lora.Linear(
#                     (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=768, out_features=32, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=32, out_features=768, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): lora.Linear(
#                     (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=768, out_features=32, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=32, out_features=768, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): BlipTextSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (crossattention): BlipTextAttention(
#                 (self): BlipTextSelfAttention(
#                   (query): lora.Linear(
#                     (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=768, out_features=32, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=32, out_features=768, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): lora.Linear(
#                     (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=768, out_features=32, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=32, out_features=768, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): BlipTextSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): BlipTextIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BlipTextOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#       )
#       (text_decoder): BlipTextLMHeadModel(
#         (bert): BlipTextModel(
#           (embeddings): BlipTextEmbeddings(
#             (word_embeddings): Embedding(30524, 768, padding_idx=0)
#             (position_embeddings): Embedding(512, 768)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (encoder): BlipTextEncoder(
#             (layer): ModuleList(
#               (0-11): 12 x BlipTextLayer(
#                 (attention): BlipTextAttention(
#                   (self): BlipTextSelfAttention(
#                     (query): lora.Linear(
#                       (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                       (lora_dropout): ModuleDict(
#                         (default): Dropout(p=0.1, inplace=False)
#                       )
#                       (lora_A): ModuleDict(
#                         (default): Linear(in_features=768, out_features=32, bias=False)
#                       )
#                       (lora_B): ModuleDict(
#                         (default): Linear(in_features=32, out_features=768, bias=False)
#                       )
#                       (lora_embedding_A): ParameterDict()
#                       (lora_embedding_B): ParameterDict()
#                       (lora_magnitude_vector): ModuleDict()
#                     )
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): lora.Linear(
#                       (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                       (lora_dropout): ModuleDict(
#                         (default): Dropout(p=0.1, inplace=False)
#                       )
#                       (lora_A): ModuleDict(
#                         (default): Linear(in_features=768, out_features=32, bias=False)
#                       )
#                       (lora_B): ModuleDict(
#                         (default): Linear(in_features=32, out_features=768, bias=False)
#                       )
#                       (lora_embedding_A): ParameterDict()
#                       (lora_embedding_B): ParameterDict()
#                       (lora_magnitude_vector): ModuleDict()
#                     )
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): BlipTextSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (crossattention): BlipTextAttention(
#                   (self): BlipTextSelfAttention(
#                     (query): lora.Linear(
#                       (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                       (lora_dropout): ModuleDict(
#                         (default): Dropout(p=0.1, inplace=False)
#                       )
#                       (lora_A): ModuleDict(
#                         (default): Linear(in_features=768, out_features=32, bias=False)
#                       )
#                       (lora_B): ModuleDict(
#                         (default): Linear(in_features=32, out_features=768, bias=False)
#                       )
#                       (lora_embedding_A): ParameterDict()
#                       (lora_embedding_B): ParameterDict()
#                       (lora_magnitude_vector): ModuleDict()
#                     )
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): lora.Linear(
#                       (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                       (lora_dropout): ModuleDict(
#                         (default): Dropout(p=0.1, inplace=False)
#                       )
#                       (lora_A): ModuleDict(
#                         (default): Linear(in_features=768, out_features=32, bias=False)
#                       )
#                       (lora_B): ModuleDict(
#                         (default): Linear(in_features=32, out_features=768, bias=False)
#                       )
#                       (lora_embedding_A): ParameterDict()
#                       (lora_embedding_B): ParameterDict()
#                       (lora_magnitude_vector): ModuleDict()
#                     )
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): BlipTextSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (intermediate): BlipTextIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): BlipTextOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#           )
#         )
#         (cls): BlipTextOnlyMLMHead(
#           (predictions): BlipTextLMPredictionHead(
#             (transform): BlipTextPredictionHeadTransform(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (transform_act_fn): GELUActivation()
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             )
#             (decoder): Linear(in_features=768, out_features=30524, bias=True)
#           )
#         )
#       )
#     )
#   )
# )

# %%
class BlipVQATestDataset(Dataset):
    def __init__(self, df, image_dir, processor):
        self.df = df
        self.image_dir = image_dir
        self.processor = processor

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        image_path = os.path.join(self.image_dir, row['path'])
        image = Image.open(image_path).convert("RGB")
        question = str(row["question"])

        inputs = self.processor(
            images=image,
            text=question,
            return_tensors="pt",
            padding='max_length',
            max_length=128,
            truncation=True
        )
        return {k: v.squeeze(0) for k, v in inputs.items()}

# %%
image_dir = "/kaggle/input/vr-dataset/small/small/"

# Prepare DataLoader
test_dataset = BlipVQATestDataset(test_df, image_dir, processor)
test_dataloader = DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers=2)

# %%
predictions = []
with torch.no_grad():
    for batch in test_dataloader:
        pixel_values = batch["pixel_values"].to(device)
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)

        outputs = model.generate(
            pixel_values=pixel_values,
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_new_tokens=10,
            use_cache=True
        )

        answers = processor.tokenizer.batch_decode(outputs, skip_special_tokens=True)
        predictions.extend(answers)

# Save or print predictions
test_df["predicted_answer"] = predictions
test_df.head(10)
# Out:
#       image_id                             question    answer  \
# 0  71OQ4BiD3uL            What is the product type?    Bucket
# 1  81CtH3N+0NL   What kind of closure does it have?   Lace-up
# 2  8176aHTRP3L           What is the primary color?     Multi
# 3  71yC+5KLN-L  What material is the cover made of?      Hard
# 4  71pP-5SEtyL   What material is the case made of?  Silicone
# 5  71A8O6XIQGL            What is the shoe's style?    Ballet
# 6  61NxifiMbuL                Is warranty included?        No
# 7  71sqlEJ6F1L         What is the case's material?   Silicon
# 8  81UrYa7KFEL              What is the heat level?    Medium
# 9  71gGW9pDoHL            What is the shoe's style?  Sneakers
#
#               path predicted_answer
# 0  f0/f0d50e0a.jpg             hand
# 1  52/521668c5.jpg             lace
# 2  43/438d87ff.jpg             pink
# 3  30/304914ac.jpg             hard
# 4  40/40d177f8.jpg           canvas
# 5  10/104a3774.jpg            heels
# 6  42/4213f453.jpg               no
# 7  3c/3ce01595.jpg           canvas
# 8  b6/b613a781.jpg           medium
# 9  e2/e2f5d987.jpg         sneakers

# %%
test_df.to_csv("vqa_predictions.csv", index=False)

# %% [markdown]
# ## METRICS

# %%
from sklearn.metrics import accuracy_score
test_df["Answer_clean"] = test_df["answer"].astype(str).str.lower().str.strip()
test_df["Pred_clean"] = test_df["predicted_answer"].astype(str).str.lower().str.strip()

acc = accuracy_score(test_df["Answer_clean"], test_df["Pred_clean"])
print(f"Exact Match Accuracy: {acc:.4f}")
# Out:
# Exact Match Accuracy: 0.2864

# %%
# !pip install bert-score
# Out:
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bert-score) (2.6.0+cu124)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from bert-score) (2.2.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from bert-score) (4.51.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.11/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from bert-score) (3.7.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from bert-score) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->bert-score) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->bert-score) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->bert-score) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->bert-score) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->bert-score) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->bert-score) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.31.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score) (2025.4.26)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=3.0.0->bert-score) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->bert-score) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->bert-score) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->bert-score) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->bert-score) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->bert-score) (2024.2.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13

# %%
from bert_score import score

# %%
filtered_df = test_df[(test_df["Answer_clean"] != "") & (test_df["Pred_clean"] != "")]

P, R, F1 = score(
    filtered_df["Pred_clean"].tolist(),
    filtered_df["Answer_clean"].tolist(),
    lang="en",
    verbose=True
)

print(f"BERTScore - Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/39 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/249 [00:00<?, ?it/s]
# done in 5.29 seconds, 3006.91 sentences/sec
# BERTScore - Precision: 0.9552, Recall: 0.9344, F1: 0.9438

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
import nltk
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn

def wups_score(preds, refs, threshold=0.9):
    def compute_wups(pred, ref):
        pred_synsets = wn.synsets(pred)
        ref_synsets = wn.synsets(ref)

        if not pred_synsets or not ref_synsets:
            return 0.0  # no synsets found → assume unrelated

        max_score = max(wn.wup_similarity(p, r) or 0.0 for p in pred_synsets for r in ref_synsets)
        return max_score

    scores = []
    for pred, ref in zip(preds, refs):
        pred = pred.lower().strip()
        ref = ref.lower().strip()

        score = compute_wups(pred, ref)
        score = score if score >= threshold else 0.0  # apply threshold
        scores.append(score)

    return sum(scores) / len(scores) if scores else 0.0

# %%
refs = test_df["Answer_clean"].tolist()
preds = test_df["Pred_clean"].tolist()

# Calculate WUPS@0.0 (lenient) and WUPS@0.9 (strict)
wups_00 = wups_score(preds, refs, threshold=0.0)
wups_09 = wups_score(preds, refs, threshold=0.9)

final_score = 0.5 * wups_00 + 0.5 * wups_09

# Print results
print(f"WUPS @0.0 (lenient): {wups_00:.4f}")
print(f"WUPS @0.9 (strict): {wups_09:.4f}")
print(f"Final Weighted WUPS Score: {final_score:.4f}")
# Out:
# WUPS @0.0 (lenient): 0.5673
# WUPS @0.9 (strict): 0.3064
# Final Weighted WUPS Score: 0.4369

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')  # Lightweight & fast

preds = test_df["predicted_answer"].astype(str).tolist()
refs = test_df["answer"].astype(str).tolist()

pred_embeds = model.encode(preds, convert_to_tensor=True)
ref_embeds = model.encode(refs, convert_to_tensor=True)

cos_sim = util.cos_sim(pred_embeds, ref_embeds).diagonal()

sbert_score = cos_sim.mean().item()
print(f"SBERT Metric: {sbert_score:.4f}")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/498 [00:00<?, ?it/s]
# Batches:   0%|          | 0/498 [00:00<?, ?it/s]
# SBERT Metric: 0.5630

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize

meteor_scores = [
    meteor_score([word_tokenize(ref)], word_tokenize(pred))
    for ref, pred in zip(test_df["answer"].astype(str), test_df["predicted_answer"].astype(str))
]

avg_meteor = sum(meteor_scores) / len(meteor_scores)
print(f"Average METEOR Score: {avg_meteor:.4f}")
# Out:
# Average METEOR Score: 0.1496
